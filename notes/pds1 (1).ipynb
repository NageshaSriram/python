# %% [markdown]
# # 05/Apr/2025

# %% [markdown]
# ####  Python for Data Science

# %%
print('Hello')
print('World')

# %% [markdown]
# #  1. Write a Program to print prime numbers from 1 to 100

# %%
print('NSE') # nse is in mumbai
# print("BSE")
print("BSE # Mumbai")

# %%
usd = '$'  inr = "\u20b9"

# %%
usd = '$' ; inr = "\u20b9"
print(usd, inr)

# %%
ord('a')

# %%
chr(98)

# %%
chr(0x20b9)

# %%
print(20)  #  nse is
in mumbai

# %%
ms1 = 'nse is 
in mumbai'

# %%
ms1 = ''' nse is 
in mumbai'''
print(ms1)
print(type(ms1))
print(len(ms1))

# %%
ms1 = 'nse'
'''
block comment 1
nse is in mumbai
'''
print(ms1)

# %%
10+20
20+30

# %%
print(10+20)
print(20+30)

# %%
'hello world'

# %%
print('hello world')

# %%
temp = 30
Temp = 40
print(temp, Temp)

# %%
91ex = 'NSE'

# %%
ex91 = 'NSE'

# %%
user@domain = "gmail"

# %%
user_domain = 'gmail'

# %%
if = 'NSE'

# %%
import keyword
print(keyword.kwlist)

# %%
global = 20

# %%
#help('modules')

# %% [markdown]
# # Indentation

# %%
sensor = 0

if sensor == 0:
    print('sensor is OFF')
    print('Switch Motor OFF')
else:
        print('Sensor ON')
        print('Motor ON')

# %%
sensor = 0

if sensor == 0:
    print('sensor is OFF')
    print('Switch Motor OFF')
else:
        print('Sensor ON')
print('Motor ON')

# %%
sensor = 0

if sensor == 0:
    print('sensor is OFF')
     print('Switch Motor OFF')
else:
        print('Sensor ON')
        print('Motor ON')

# %%
# all statements within a block, must have same indentation

# %%
print(dir(__builtins__))

# %%
print(dir(keyword))

# %%
print(dir(str))

# %% [markdown]
# # Assignment

# %%
v1 = 20
print(type(v1))
print(id(v1))
print(v1)

v1 = 'hello'
print(type(v1))
print(id(v1))
print(v1)

# %%
# in python , there is no contract bn the variable name and the memory of the object

# %%
a=b=c = 2345
print(a,b,c)

# %%
v0,v1,v2 = 'hello', 2345, [111,222,333]  # positional mapping.
print(v0, type (v0))
print(v1, type (v1))
print(v2, type (v2))

# %% [markdown]
# # Keyboard Input

# %%
s1 = input('Enter sub name: ')
print(type(s1))
print(len(s1))
print(s1)

# %%
n1 = input('Enter Marks: ')
print(type(n1))
print(len(n1))
print(n1)
n2 = n1 + 10
print(n2)

# %%
int('10')

# %%
int('hello')

# %%
n1 = input('Enter Marks: ')
print(type(n1))
print(len(n1))
print(n1)
n2 = int(n1) + 10
print(n2)

# %%
int('98.76')

# %%
float('98.76')

# %%
int(98.76)

# %%
float(23)
